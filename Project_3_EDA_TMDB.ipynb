# %% [markdown]
# <a href="https://colab.research.google.com/github/Issey2023/Data-Enrichment-Project-3/blob/main/Project_3_EDA_TMDB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # EDA
# **Student: Ismaa-eel Hendricks**

# %% [markdown]
# # Imports

# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
df_2000=pd.read_csv('Data/final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
df_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1209 entries, 0 to 1208
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1209 non-null   object
#  1   adult                  1208 non-null   float64
#  2   backdrop_path          645 non-null    object
#  3   belongs_to_collection  111 non-null    object
#  4   budget                 1208 non-null   float64
#  5   genres                 1208 non-null   object
#  6   homepage               68 non-null     object
#  7   id                     1208 non-null   float64
#  8   original_language      1208 non-null   object
#  9   original_title         1208 non-null   object
#  10  overview               1186 non-null   object
#  11  popularity             1208 non-null   float64
#  12  poster_path            1074 non-null   object
#  13  production_companies   1208 non-null   object
# ...

# %%
df_2001 = pd.read_csv('Data/final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0114447    0.0                               NaN                   NaN
# 3  tt0118589    0.0  /9NZAirJahVilTiDNCHLFcdkwkiy.jpg                   NaN
# 4  tt0118652    0.0  /mWxJEFRMvkG4UItYJkRDMgWQ08Y.jpg                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
# 3  22000000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...      NaN
# 4   1000000.0  [{'id': 27, 'name': 'Horror'}, {'id': 9648, 'n...      NaN
#
# ...

# %%
df_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1293 entries, 0 to 1292
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                1293 non-null   object
#  1   adult                  1292 non-null   float64
#  2   backdrop_path          666 non-null    object
#  3   belongs_to_collection  86 non-null     object
#  4   budget                 1292 non-null   float64
#  5   genres                 1292 non-null   object
#  6   homepage               107 non-null    object
#  7   id                     1292 non-null   float64
#  8   original_language      1292 non-null   object
#  9   original_title         1292 non-null   object
#  10  overview               1263 non-null   object
#  11  popularity             1292 non-null   float64
#  12  poster_path            1144 non-null   object
#  13  production_companies   1292 non-null   object
# ...

# %% [markdown]
# # Cleaning

# %%
df_2001.duplicated().sum()
# Out:
# 0

# %%
df_2001.isna().sum()
# Out:
# imdb_id                     0
# adult                       1
# backdrop_path             627
# belongs_to_collection    1207
# budget                      1
# genres                      1
# homepage                 1186
# id                          1
# original_language           1
# original_title              1
# overview                   30
# popularity                  1
# poster_path               149
# production_companies        1
# production_countries        1
# release_date                8
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                   760
# title                       1
# video                       1
# vote_average                1
# vote_count                  1
# certification             872
# dtype: int64

# %%
df_2000.duplicated().sum()
# Out:
# 0

# %%
df_2000.isna().sum()
# Out:
# imdb_id                     0
# adult                       1
# backdrop_path             564
# belongs_to_collection    1098
# budget                      1
# genres                      1
# homepage                 1141
# id                          1
# original_language           1
# original_title              1
# overview                   23
# popularity                  1
# poster_path               135
# production_companies        1
# production_countries        1
# release_date               10
# revenue                     1
# runtime                     1
# spoken_languages            1
# status                      1
# tagline                   693
# title                       1
# video                       1
# vote_average                1
# vote_count                  1
# certification             833
# dtype: int64

# %% [markdown]
# # Merging

# %%
df_concat = pd.concat([df_2000,df_2001])

# %%
df_concat.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0113026    0.0  /vMFs7nw6P0bIV1jDsQpxAieAVnH.jpg                   NaN
# 2  tt0113092    0.0                               NaN                   NaN
# 3  tt0116391    0.0                               NaN                   NaN
# 4  tt0118694    0.0  /n4GJFGzsc7NinI1VeGDXIcQjtU2.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  10000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 2         0.0           [{'id': 878, 'name': 'Science Fiction'}]
# 3         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 28, 'name...
# 4    150000.0  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
#
#                                homepage        id original_language  \
# ...

# %%
df_concat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2502 entries, 0 to 1292
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2502 non-null   object
#  1   adult                  2500 non-null   float64
#  2   backdrop_path          1311 non-null   object
#  3   belongs_to_collection  197 non-null    object
#  4   budget                 2500 non-null   float64
#  5   genres                 2500 non-null   object
#  6   homepage               175 non-null    object
#  7   id                     2500 non-null   float64
#  8   original_language      2500 non-null   object
#  9   original_title         2500 non-null   object
#  10  overview               2449 non-null   object
#  11  popularity             2500 non-null   float64
#  12  poster_path            2218 non-null   object
#  13  production_companies   2500 non-null   object
# ...

# %% [markdown]
# # Q1

# %%
df_concat.groupby('budget')['revenue'].value_counts().sum()
# Out:
# 2500

# %% [markdown]
# # Q2

# %%
df_concat.groupby('certification')['budget'].describe()
# Out:
#                count          mean           std  min  25%         50%  \
# certification
# -                1.0  0.000000e+00           NaN  0.0  0.0         0.0
# G               24.0  2.383333e+07  3.310283e+07  0.0  0.0  13000000.0
# NC-17            6.0  0.000000e+00  0.000000e+00  0.0  0.0         0.0
# NR              68.0  1.575001e+06  7.506164e+06  0.0  0.0         0.0
# PG              64.0  2.459766e+07  3.818498e+07  0.0  0.0     75002.0
# PG-13          181.0  3.123154e+07  3.389891e+07  0.0  0.0  22000000.0
# R              452.0  9.998904e+06  1.985928e+07  0.0  0.0         0.0
# Unrated          1.0  0.000000e+00           NaN  0.0  0.0         0.0
#
#                       75%          max
# certification
# -                     0.0          0.0
# G              31250000.0  115000000.0
# NC-17                 0.0          0.0
# NR                    0.0   60000000.0
# PG             35750000.0  127500000.0
# PG-13          50000000.0  140000000.0
# ...

# %% [markdown]
# G:     24
# NC-17: 6
# NR:    68
# PG:    64
# Pg-13: 181
# R:     452
# UR:    1

# %% [markdown]
# # Q3 & Q4

# %%
ax = sns.barplot(data=df_concat, x ='certification',y='budget',ci=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);                         ##budget is in millions

# %%
ax = sns.barplot(data=df_concat, x ='certification',y='revenue',ci=None)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90);                        ## Revenue is in millions
